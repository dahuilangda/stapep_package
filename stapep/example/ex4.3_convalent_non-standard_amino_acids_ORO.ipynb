# %%
# Using stapep.generate_covalent_template to generate parameter templates for non-standard amino acids
# --smiles1: The first non-standard amino acid SMILES, including COOH and NH2 on the main chain
# --name1: The first non-standard amino acid name, must be 3 uppercase characters
# --smiles2: The second non-standard amino acid SMILES, including COOH and NH2 on the main chain
# --name2: The second non-standard amino acid name, must be 3 uppercase characters
# --nbonds: The number of bonds between the two non-standard amino acids
# --charge1: The charge of the first non-standard amino acid, if not specified, it will default to 0.0
# --charge2: The charge of the second non-standard amino acid, if not specified, it will default to 0.0
# --output: Output path, if not specified, it will default to the name folder in the current directory

# The generated parameter templates will be saved in the output path, and the parameter templates will be named as "R1A_R2A"
# !rm -rf data/ORO

# Generate parameter templates for non-standard amino acids
# smiles1 and smiles2 must include * to represent the connection point and the main chain must include COOH and NH2
# !python -m stapep.generate_covalent_template \
    --smiles1 "N=C(NCCC[C@@H](N)C(=O)O)NCCOC[*]" \
    --name1 ORA \
    --smiles2 "N=C(NC[*:2])NCCC[C@@H](N)C(=O)O" \
    --name2 ORB \
    --nbonds 1 \
    --output data/ORO

# Output the generated parameter templates of covalent non-standard amino acids
# 1. R1A.prepin and R1A.frcmod: The parameter files for the first non-standard amino acid
# 2. R2A.prepin and R2A.frcmod: The parameter files for the second non-standard amino acid
# 3. covalent_info.csv: The covalent information file
# Out:
# args.smiles1: N=C(NCCC[C@@H](N)C(=O)O)NCCOC[*]
# args.smiles2: N=C(NC[*:2])NCCC[C@@H](N)C(=O)O
# antechamber -fi sdf -i ORA.sdf -bk ORA -fo ac -o ORA.ac -c bcc -at amber
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to amber; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for sdf File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
#    Status: pass
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
# Info: Total number of electrons: 126; net charge: 0
#
# Running: /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/sqm -O -i sqm.in -o sqm.out
#
# antechamber -fi sdf -i ORB.sdf -bk ORB -fo ac -o ORB.ac -c bcc -at amber
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to amber; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for sdf File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
#    Status: pass
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
# Info: Total number of electrons: 102; net charge: 0
#
# Running: /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/sqm -O -i sqm.in -o sqm.out
#
# antechamber -fi ac -i ORA.ac -bk ORA -fo pdb -o ORA.pdb
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to gaff; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for ac File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
# Warning: The number of bonds (2) for atom (ID: 1, Name: N1) does not match
#          the connectivity (3) for atom type (N2) defined in CORR_NAME_TYPE.DAT.
# But, you may safely ignore the warnings if your molecule
#          uses atom names or element names as atom types.
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
#
# antechamber -fi ac -i ORB.ac -bk ORB -fo pdb -o ORB.pdb
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to gaff; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for ac File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
# Warning: The number of bonds (2) for atom (ID: 1, Name: N1) does not match
#          the connectivity (3) for atom type (N2) defined in CORR_NAME_TYPE.DAT.
# But, you may safely ignore the warnings if your molecule
#          uses atom names or element names as atom types.
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
#
# [18:52:20] WARNING: More than one matching pattern found - picking one
#
# [18:52:20] WARNING: More than one matching pattern found - picking one
#
# [18:52:20] WARNING: More than one matching pattern found - picking one
#
# [18:52:20] WARNING: More than one matching pattern found - picking one
#
# atom.GetSymbol(): C1
# atom.GetSymbol(): N1
# atom.GetSymbol(): C1
# atom.GetSymbol(): N2
# atom.GetSymbol(): C2
# atom.GetSymbol(): C3
# atom.GetSymbol(): C4
# atom.GetSymbol(): C5
# atom.GetSymbol(): C5
# atom.GetSymbol(): C6
# atom.GetSymbol(): C6
# atom.GetSymbol(): C1
# atom.GetSymbol(): N4
# atom.GetSymbol(): C7
# atom.GetSymbol(): C8
# atom.GetSymbol(): O3
# atom.GetSymbol(): N1
# atom.GetSymbol(): N2
# atom.GetSymbol(): C2
# atom.GetSymbol(): C2
# atom.GetSymbol(): C3
# atom.GetSymbol(): C3
# atom.GetSymbol(): C4
# atom.GetSymbol(): C4
# atom.GetSymbol(): C5
# atom.GetSymbol(): N3
# atom.GetSymbol(): N3
# atom.GetSymbol(): O2
# atom.GetSymbol(): N4
# atom.GetSymbol(): C7
# atom.GetSymbol(): C7
# atom.GetSymbol(): C8
# atom.GetSymbol(): C8
# atom.GetSymbol(): C9
# atom.GetSymbol(): C1
# atom.GetSymbol(): N1
# atom.GetSymbol(): C1
# atom.GetSymbol(): N2
# atom.GetSymbol(): C1
# atom.GetSymbol(): N3
# atom.GetSymbol(): C3
# atom.GetSymbol(): C4
# atom.GetSymbol(): C5
# atom.GetSymbol(): C6
# atom.GetSymbol(): C6
# atom.GetSymbol(): C7
# atom.GetSymbol(): C7
# atom.GetSymbol(): N1
# atom.GetSymbol(): N2
# atom.GetSymbol(): C2
# prepgen -i ORA.ac -o ORA.prepin -m ORA.mc -rn ORA
#
# PRE_HEAD_TYPE is     C
# Net charge of truncated molecule is     0.00
# HEAD_ATOM      8   N3
# TAIL_ATOM      9   C6
# MAIN_CHAIN     1    8   N3
# MAIN_CHAIN     2    7   C5
# MAIN_CHAIN     3    9   C6
# OMIT_ATOM      1   34  H18
# OMIT_ATOM      2   11   O2
# OMIT_ATOM      3   28  H12
# OMIT_ATOM      4   26  H10
# Number of mainchain atoms (including head and tail atom):     3
# Number of omited atoms:     4
# Info: There is a bond linking a non-head and non-tail residue atom (C9) and an omitted atom (H18).
#       You need to specifically add this bond in LEaP using the command 'bond <atom1> <atom2> [order]'
#       to link C9 to an atom in another residue (similar to disulfide bonds)!
# prepgen -i ORB.ac -o ORB.prepin -m ORB.mc -rn ORB
#
# PRE_HEAD_TYPE is     C
# Net charge of truncated molecule is     0.00
# HEAD_ATOM     10   N4
# TAIL_ATOM     11   C7
# MAIN_CHAIN     1   10   N4
# MAIN_CHAIN     2    9   C6
# MAIN_CHAIN     3   11   C7
# OMIT_ATOM      1   16   H3
# OMIT_ATOM      2   13   O2
# OMIT_ATOM      3   29  H16
# OMIT_ATOM      4   27  H14
# Number of mainchain atoms (including head and tail atom):     3
# Number of omited atoms:     4
# Info: There is a bond linking a non-head and non-tail residue atom (C2) and an omitted atom (H3).
#       You need to specifically add this bond in LEaP using the command 'bond <atom1> <atom2> [order]'
#       to link C2 to an atom in another residue (similar to disulfide bonds)!
# sed -i 's/N3    NT/N     N /g' ORA.prepin
# sed -i 's/C6    C/C     C/g' ORA.prepin
# sed -i 's/O1    O/O     O/g' ORA.prepin
# sed -i 's/C5    CT/CA    CT/g' ORA.prepin
# sed -i 's/N4    NT/N     N /g' ORB.prepin
# sed -i 's/C7    C/C     C/g' ORB.prepin
# sed -i 's/O1    O/O     O/g' ORB.prepin
# sed -i 's/C6    CT/CA    CT/g' ORB.prepin
# parmchk2 -i ORA.prepin -f prepi -o frcmod.ORA -a Y
# parmchk2 -i ORB.prepin -f prepi -o frcmod.ORB -a Y
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/parmchk2: line 9: 2761075 Segmentation fault      (core dumped) "$AMBERHOME/bin/wrapped_progs/parmchk2" "$@"
# No dummy atom [*] found in the SMILES
# antechamber -fi sdf -i ORA_ORB.sdf -bk ORA_ORB -fo ac -o ORA_ORB.ac -c bcc -at amber
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to amber; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for sdf File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
#    Status: pass
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
# Info: Total number of electrons: 226; net charge: 0
#
# Running: /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/sqm -O -i sqm.in -o sqm.out
#
# antechamber -fi ac -i ORA_ORB.ac -bk ORA_ORB -fo pdb -o ORA_ORB.pdb
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to gaff; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for ac File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
# Warning: The number of bonds (2) for atom (ID: 1, Name: N1) does not match
#          the connectivity (3) for atom type (N2) defined in CORR_NAME_TYPE.DAT.
# Warning: The number of bonds (2) for atom (ID: 20, Name: N6) does not match
#          the connectivity (3) for atom type (N2) defined in CORR_NAME_TYPE.DAT.
# But, you may safely ignore the warnings if your molecule
#          uses atom names or element names as atom types.
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
#
# parmchk2 -i ORA_ORB.ac -f ac -o frcmod.ORA_ORB -a Y

# %%
# Show the structure of the non-standard amino acids

from rdkit import Chem
from rdkit.Chem import Draw

# smiles1 and smiles2 must include * to represent the connection point and the main chain must include COOH and NH2
smiles1 = "N=C(NCCC[C@@H](N)C(=O)O)NCCOC[*:1]"
smiles2 = "N=C(NCCC[C@@H](N)C(=O)O)NCC[*:2]"
molecule1 = Chem.MolFromSmiles(smiles1)
molecule2 = Chem.MolFromSmiles(smiles2)
Draw.MolsToGridImage([molecule1, molecule2], molsPerRow=2)

# %%
import os
import pandas as pd
# os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com' # 国内用户取消注释这一行
from stapep.structure import Structure
from stapep.molecular_dynamics import PrepareProt

# Define the additional_residues and covalent_info
additional_residues = {
    'ORA': (
        'data/ORO/ORA.prepin',
        'data/ORO/frcmod.ORA',
    ),
    'ORB': (
        'data/ORO/ORB.prepin',
        'data/ORO/frcmod.ORB',
    )
}

covalent_info = pd.read_csv('data/ORO/covalent_info.csv')

output = 'MD' # Define the output directory for the 3D structure prediction
seq = 'Ac-GIGKFLHSAKKFGKA-ORA-VGE-ORB-BNS-NH2' # Define the peptide sequence
# De novo 3D structure prediction using ESMFOLD
st = Structure(verbose=True)
pp = PrepareProt(seq, output, method='alphafold', additional_residues=additional_residues, covalent_info=covalent_info)
pp._gen_prmtop_and_inpcrd_file()
st.de_novo_3d_structure(seq, 
                        output_pdb='MD/demo.pdb',
                        additional_residues=additional_residues,
                        covalent_info=covalent_info)
# Out:
# /home/dahuilangda/Simulation/miniconda3/envs/stap/lib/python3.9/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# Some weights of EsmForProteinFolding were not initialized from the model checkpoint at facebook/esmfold_v1 and are newly initialized: ['esm.contact_head.regression.weight', 'esm.contact_head.regression.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/prep to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd to search path.
# -f: Source tleap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./tleap.in
# ----- Source: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.protein.ff14SB
# ----- Source of /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.protein.ff14SB done
# Log file: ./leap.log
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ff14SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff14SB protein backbone and sidechain parameters
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/amino12.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/aminoct12.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/aminont12.lib
# ----- Source: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.water.tip3p
# ----- Source of /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.water.tip3p done
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/atomic_ions.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/solvents.lib
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# This is the additional/replacement parameter set for TIP3P water
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ions1lm_126_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of monovalent ions for TIP3P water model (12-6 normal usage set)
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ionsjc_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Monovalent ion parameters for Ewald and TIP3P water from Joung & Cheatham JPCB (2008)
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ions234lm_126_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of divalent to tetravalent ions for TIP3P water model (12-6 normal usage set)
# Using ArgH and AspGluO modified Bondi2 radii
# Loading Prep file: /home/dahuilangda/Simulation/miniconda3/envs/stap/lib/python3.9/site-packages/stapep-0.2.1-py3.9.egg/stapep/templates/NLE/nle.prepin
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/lib/python3.9/site-packages/stapep-0.2.1-py3.9.egg/stapep/templates/NLE/frcmod.nle
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORA_ORB
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Loading Prep file: /home/dahuilangda/Work/20251215_SYJ/data/ORO/ORA.prepin
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C5 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C6 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom O1 not found
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORA
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Loading Prep file: /home/dahuilangda/Work/20251215_SYJ/data/ORO/ORB.prepin
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C6 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C7 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom O1 not found
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORB
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Error!
# Modified force field files must have both MASS and NONBOND entries or neither.
# Could not load parameter set from /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORB.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# -- no parameters loadedLoading PDB file: ./model.pdb
#   Added missing heavy atom: .R<ACE 0>.A<CH3 2>
#   Added missing heavy atom: .R<ACE 0>.A<O 6>
#   Added missing heavy atom: .R<ORA 16>.A<C4 4>
#   Added missing heavy atom: .R<ORA 16>.A<C3 5>
#   Added missing heavy atom: .R<ORA 16>.A<C2 6>
#   Added missing heavy atom: .R<ORA 16>.A<N2 7>
#   Added missing heavy atom: .R<ORA 16>.A<C1 8>
#   Added missing heavy atom: .R<ORA 16>.A<N1 9>
#   Added missing heavy atom: .R<ORA 16>.A<N4 11>
#   Added missing heavy atom: .R<ORA 16>.A<C7 12>
#   Added missing heavy atom: .R<ORA 16>.A<C8 13>
#   Added missing heavy atom: .R<ORA 16>.A<O3 14>
#   Added missing heavy atom: .R<ORA 16>.A<C9 15>
#   Added missing heavy atom: .R<ORB 20>.A<C5 4>
#   Added missing heavy atom: .R<ORB 20>.A<C4 5>
#   Added missing heavy atom: .R<ORB 20>.A<C3 6>
#   Added missing heavy atom: .R<ORB 20>.A<N3 7>
#   Added missing heavy atom: .R<ORB 20>.A<C1 8>
#   Added missing heavy atom: .R<ORB 20>.A<N1 9>
#   Added missing heavy atom: .R<ORB 20>.A<N2 11>
#   Added missing heavy atom: .R<ORB 20>.A<C2 12>
#   Added missing heavy atom: .R<NLE 21>.A<C4 4>
#   Added missing heavy atom: .R<NLE 21>.A<C3 5>
#   Added missing heavy atom: .R<NLE 21>.A<C2 6>
#   Added missing heavy atom: .R<NLE 21>.A<C1 7>
#   Added missing heavy atom: .R<NME 24>.A<C 3>
#   total atoms in file: 160
#   Leap added 226 missing atoms according to residue templates:
#        26 Heavy
#        200 H / lone pairs
# Checking Unit.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 16.342 angstroms between C9 and C2 atoms:
# -------  .R<ORA 16>.A<C9 15> and .R<ORB 20>.A<C2 12>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 3.600 angstroms between C and N atoms:
# -------  .R<SER 23>.A<C 10> and .R<NME 24>.A<N 1>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# The unperturbed charge of the unit (2.999995) is not zero.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# Ignoring the warnings from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
# old PREP-specified impropers:
#  <ORA 16>:  N1   N4   C1   N2
#  <ORB 20>:  N1   N2   C1   N3
#  <NLE 21>:  CA   +M   C    O
#  total 69 improper torsions applied
#  3 improper torsions in old prep form
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#  (no restraints)
# Writing pdb file: pep_vac.pdb
#   Solute vdw bounding box:              23.434 24.710 44.653
#   Total bounding box for atom centers:  43.434 44.710 64.653
#   Solvent unit box:                     18.774 18.774 18.774
#   Total vdw box size:                   46.645 47.921 67.771 angstroms.
#   Volume: 151487.270 A^3
#   Total mass 67504.776 amu,  Density 0.740 g/cc
#   Added 3601 residues.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# addIons: 1st Ion & target unit have charges of the same sign:
#      unit charge = 2.99999; ion1 charge = 1;
#      can't neutralize.
# 3 Cl- ions required to neutralize.
# Adding 3 counter ions to "pep" using 1A grid
# Grid extends from solute vdw + 2.51  to  8.42
# Resolution:      1.00 Angstrom.
# Solvent present: replacing closest with ion
# 	 when steric overlaps occur
# Calculating grid charges
# (No solvent overlap)
# Placed Cl- in pep at (-2.69, 8.79, -7.86).
# (Replacing solvent molecule)
# Placed Cl- in pep at (-8.67, 3.32, -15.92).
# (Replacing solvent molecule)
# Placed Cl- in pep at (-8.22, -10.04, -16.81).
#
# Done adding ions.
# Checking Unit.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 16.342 angstroms between C9 and C2 atoms:
# -------  .R<ORA 16>.A<C9 15> and .R<ORB 20>.A<C2 12>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 3.600 angstroms between C and N atoms:
# -------  .R<SER 23>.A<C 10> and .R<NME 24>.A<N 1>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# Ignoring the warnings from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
# old PREP-specified impropers:
#  <ORA 16>:  N1   N4   C1   N2
#  <ORB 20>:  N1   N2   C1   N3
#  <NLE 21>:  CA   +M   C    O
#  total 69 improper torsions applied
#  3 improper torsions in old prep form
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	WAT	3599
#   )
#  (no restraints)
# Writing pdb file: pep_solv.pdb
#    printing CRYST1 record to PDB file with box info
# 	Quit
#
# Exiting LEaP: Errors = 1; Warnings = 6; Notes = 9.
# Some weights of EsmForProteinFolding were not initialized from the model checkpoint at facebook/esmfold_v1 and are newly initialized: ['esm.contact_head.regression.weight', 'esm.contact_head.regression.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:parmed.structure:Adding bonds...
# INFO:parmed.structure:Adding angles...
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/prep to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd to search path.
# -f: Source tleap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./tleap.in
# ----- Source: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.protein.ff14SB
# ----- Source of /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.protein.ff14SB done
# Log file: ./leap.log
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ff14SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff14SB protein backbone and sidechain parameters
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/amino12.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/aminoct12.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/aminont12.lib
# ----- Source: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.water.tip3p
# ----- Source of /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.water.tip3p done
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/atomic_ions.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/solvents.lib
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# This is the additional/replacement parameter set for TIP3P water
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ions1lm_126_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of monovalent ions for TIP3P water model (12-6 normal usage set)
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ionsjc_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Monovalent ion parameters for Ewald and TIP3P water from Joung & Cheatham JPCB (2008)
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ions234lm_126_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of divalent to tetravalent ions for TIP3P water model (12-6 normal usage set)
# Using ArgH and AspGluO modified Bondi2 radii
# Loading Prep file: /home/dahuilangda/Simulation/miniconda3/envs/stap/lib/python3.9/site-packages/stapep-0.2.1-py3.9.egg/stapep/templates/NLE/nle.prepin
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/lib/python3.9/site-packages/stapep-0.2.1-py3.9.egg/stapep/templates/NLE/frcmod.nle
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORA_ORB
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Loading Prep file: /home/dahuilangda/Work/20251215_SYJ/data/ORO/ORA.prepin
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C5 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C6 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom O1 not found
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORA
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Loading Prep file: /home/dahuilangda/Work/20251215_SYJ/data/ORO/ORB.prepin
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C6 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C7 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom O1 not found
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORB
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Error!
# Modified force field files must have both MASS and NONBOND entries or neither.
# Could not load parameter set from /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORB.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# -- no parameters loadedLoading PDB file: ./model.pdb
#   Added missing heavy atom: .R<ACE 0>.A<CH3 2>
#   Added missing heavy atom: .R<ACE 0>.A<O 6>
#   Added missing heavy atom: .R<ORA 16>.A<C4 4>
#   Added missing heavy atom: .R<ORA 16>.A<C3 5>
#   Added missing heavy atom: .R<ORA 16>.A<C2 6>
#   Added missing heavy atom: .R<ORA 16>.A<N2 7>
#   Added missing heavy atom: .R<ORA 16>.A<C1 8>
#   Added missing heavy atom: .R<ORA 16>.A<N1 9>
#   Added missing heavy atom: .R<ORA 16>.A<N4 11>
#   Added missing heavy atom: .R<ORA 16>.A<C7 12>
#   Added missing heavy atom: .R<ORA 16>.A<C8 13>
#   Added missing heavy atom: .R<ORA 16>.A<O3 14>
#   Added missing heavy atom: .R<ORA 16>.A<C9 15>
#   Added missing heavy atom: .R<ORB 20>.A<C5 4>
#   Added missing heavy atom: .R<ORB 20>.A<C4 5>
#   Added missing heavy atom: .R<ORB 20>.A<C3 6>
#   Added missing heavy atom: .R<ORB 20>.A<N3 7>
#   Added missing heavy atom: .R<ORB 20>.A<C1 8>
#   Added missing heavy atom: .R<ORB 20>.A<N1 9>
#   Added missing heavy atom: .R<ORB 20>.A<N2 11>
#   Added missing heavy atom: .R<ORB 20>.A<C2 12>
#   Added missing heavy atom: .R<NLE 21>.A<C4 4>
#   Added missing heavy atom: .R<NLE 21>.A<C3 5>
#   Added missing heavy atom: .R<NLE 21>.A<C2 6>
#   Added missing heavy atom: .R<NLE 21>.A<C1 7>
#   Added missing heavy atom: .R<NME 24>.A<C 3>
#   total atoms in file: 160
#   Leap added 226 missing atoms according to residue templates:
#        26 Heavy
#        200 H / lone pairs
# Checking Unit.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 16.342 angstroms between C9 and C2 atoms:
# -------  .R<ORA 16>.A<C9 15> and .R<ORB 20>.A<C2 12>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 3.600 angstroms between C and N atoms:
# -------  .R<SER 23>.A<C 10> and .R<NME 24>.A<N 1>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# The unperturbed charge of the unit (2.999995) is not zero.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# Ignoring the warnings from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
# old PREP-specified impropers:
#  <ORA 16>:  N1   N4   C1   N2
#  <ORB 20>:  N1   N2   C1   N3
#  <NLE 21>:  CA   +M   C    O
#  total 69 improper torsions applied
#  3 improper torsions in old prep form
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#  (no restraints)
# Writing pdb file: pep_vac.pdb
#   Solute vdw bounding box:              23.434 24.710 44.653
#   Total bounding box for atom centers:  43.434 44.710 64.653
#   Solvent unit box:                     18.774 18.774 18.774
#   Total vdw box size:                   46.645 47.921 67.771 angstroms.
#   Volume: 151487.270 A^3
#   Total mass 67504.776 amu,  Density 0.740 g/cc
#   Added 3601 residues.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# addIons: 1st Ion & target unit have charges of the same sign:
#      unit charge = 2.99999; ion1 charge = 1;
#      can't neutralize.
# 3 Cl- ions required to neutralize.
# Adding 3 counter ions to "pep" using 1A grid
# Grid extends from solute vdw + 2.51  to  8.42
# Resolution:      1.00 Angstrom.
# Solvent present: replacing closest with ion
# 	 when steric overlaps occur
# Calculating grid charges
# (No solvent overlap)
# Placed Cl- in pep at (-2.69, 8.79, -7.86).
# (Replacing solvent molecule)
# Placed Cl- in pep at (-8.67, 3.32, -15.92).
# (Replacing solvent molecule)
# Placed Cl- in pep at (-8.22, -10.04, -16.81).
#
# Done adding ions.
# Checking Unit.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 16.342 angstroms between C9 and C2 atoms:
# -------  .R<ORA 16>.A<C9 15> and .R<ORB 20>.A<C2 12>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 3.600 angstroms between C and N atoms:
# -------  .R<SER 23>.A<C 10> and .R<NME 24>.A<N 1>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# Ignoring the warnings from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
# old PREP-specified impropers:
#  <ORA 16>:  N1   N4   C1   N2
#  <ORB 20>:  N1   N2   C1   N3
#  <NLE 21>:  CA   +M   C    O
#  total 69 improper torsions applied
#  3 improper torsions in old prep form
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	WAT	3599
#   )
#  (no restraints)
# Writing pdb file: pep_solv.pdb
#    printing CRYST1 record to PDB file with box info
# 	Quit
#
# Exiting LEaP: Errors = 1; Warnings = 6; Notes = 9.
# INFO:parmed.structure:Adding dihedrals...
# INFO:parmed.structure:Adding Ryckaert-Bellemans torsions...
# INFO:parmed.structure:Adding Urey-Bradleys...
# INFO:parmed.structure:Adding improper torsions...
# INFO:parmed.structure:Adding CMAP torsions...
# INFO:parmed.structure:Adding trigonal angle terms...
# INFO:parmed.structure:Adding out-of-plane bends...
# INFO:parmed.structure:Adding pi-torsions...
# INFO:parmed.structure:Adding stretch-bends...
# INFO:parmed.structure:Adding torsion-torsions...
# INFO:parmed.structure:Adding Nonbonded force...
# INFO:parmed.structure:Adding GB force...
# INFO:root:Running short time simulation for 100000 steps
# Minimizing...
# Running...
# Done! Time elapsed: 17.32022738456726 s
# /tmp/b618abd9-004a-41ed-84ac-b08f0790c85e/traj.dcd /tmp/b618abd9-004a-41ed-84ac-b08f0790c85e/pep_vac.prmtop
# 'MD/demo.pdb'

# %%
import py3Dmol
from stapep.utils import ProtParamsSeq

from rdkit.Chem import Descriptors

# Define the stapled residue names
covalent_resnames = ['ORA', 'ORB']

additional_params = {
    'weight': {
        'ORA': Descriptors.ExactMolWt(molecule1),
        'ORB': Descriptors.ExactMolWt(molecule2)
    }
}

# Process the sequence to locate stapled residues
pps = ProtParamsSeq(seq, additional_params=additional_params)
seq_ = pps.seq_to_list
covalent_residues = [seq_.index(s)+1 for s in seq_ if s in covalent_resnames]

# Load the PDB file
p = py3Dmol.view(query='data/demo.pdb')

# Set default style as cartoon
p.setStyle({'model': 0}, {'cartoon': {'color': 'gray'}})

# Highlight stapled residues with stick style
for res in covalent_residues:
    p.addStyle({'model': 0, 'resi': res}, {'stick': {'color': 'orange'}})

# Adjust the view
p.zoomTo()

# Display the visualization
p.show()
# Out:
# <div id="3dmolviewer_17657964384814801"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17657964384814801" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17657964384814801 = null;
# var warn = document.getElementById("3dmolwarning_17657964384814801");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17657964384814801 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17657964384814801"),{backgroundColor:"white"});
# $3Dmol.download("data/demo.pdb", viewer_17657964384814801, {}, function() {
# viewer_17657964384814801.zoomTo();
# 	viewer_17657964384814801.setStyle({"model": 0},{"cartoon": {"color": "gray"}});
# 	viewer_17657964384814801.addStyle({"model": 0, "resi": 17},{"stick": {"color": "orange"}});
# 	viewer_17657964384814801.addStyle({"model": 0, "resi": 21},{"stick": {"color": "orange"}});
# 	viewer_17657964384814801.zoomTo();
# viewer_17657964384814801.render();
# })
# });
# </script>

# %% [markdown]
# # Molecular Dynamics

# %%
import os
import pandas as pd
# os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com' # 国内用户取消注释这一行
from stapep.molecular_dynamics import PrepareProt

# Define the additional_residues and covalent_info
additional_residues = {
    'ORA': (
        'data/ORO/ORA.prepin',
        'data/ORO/frcmod.ORA',
    ),
    'ORB': (
        'data/ORO/ORB.prepin',
        'data/ORO/frcmod.ORB',
    )
}

covalent_info = pd.read_csv('data/ORO/covalent_info.csv')

output = 'data'
seq = 'SSKL-ORA-QLLF-ORB' # Define the peptide sequence
pp = PrepareProt(seq, output, method='alphafold', additional_residues=additional_residues, covalent_info=covalent_info)
pp._gen_prmtop_and_inpcrd_file()
# Out:
# Some weights of EsmForProteinFolding were not initialized from the model checkpoint at facebook/esmfold_v1 and are newly initialized: ['esm.contact_head.regression.weight', 'esm.contact_head.regression.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/prep to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm to search path.
# -I: Adding /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd to search path.
# -f: Source tleap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./tleap.in
# ----- Source: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.protein.ff14SB
# ----- Source of /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.protein.ff14SB done
# Log file: ./leap.log
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ff14SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff14SB protein backbone and sidechain parameters
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/amino12.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/aminoct12.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/aminont12.lib
# ----- Source: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.water.tip3p
# ----- Source of /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/cmd/leaprc.water.tip3p done
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/atomic_ions.lib
# Loading library: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/lib/solvents.lib
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# This is the additional/replacement parameter set for TIP3P water
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ions1lm_126_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of monovalent ions for TIP3P water model (12-6 normal usage set)
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ionsjc_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Monovalent ion parameters for Ewald and TIP3P water from Joung & Cheatham JPCB (2008)
# Loading parameters: /home/dahuilangda/Simulation/miniconda3/envs/stap/dat/leap/parm/frcmod.ions234lm_126_tip3p
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of divalent to tetravalent ions for TIP3P water model (12-6 normal usage set)
# Using ArgH and AspGluO modified Bondi2 radii
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORA_ORB
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Loading Prep file: /home/dahuilangda/Work/20251215_SYJ/data/ORO/ORA.prepin
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C5 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C6 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom O1 not found
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORA
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Loading Prep file: /home/dahuilangda/Work/20251215_SYJ/data/ORO/ORB.prepin
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C6 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom C7 not found
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# ** This is a remark line: 'IMPROPER' atom O1 not found
# Loading parameters: /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORB
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Error!
# Modified force field files must have both MASS and NONBOND entries or neither.
# Could not load parameter set from /home/dahuilangda/Work/20251215_SYJ/data/ORO/frcmod.ORB.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# -- no parameters loadedLoading PDB file: ./model.pdb
#   Added missing heavy atom: .R<ORA 5>.A<C4 4>
#   Added missing heavy atom: .R<ORA 5>.A<C3 5>
#   Added missing heavy atom: .R<ORA 5>.A<C2 6>
#   Added missing heavy atom: .R<ORA 5>.A<N2 7>
#   Added missing heavy atom: .R<ORA 5>.A<C1 8>
#   Added missing heavy atom: .R<ORA 5>.A<N1 9>
#   Added missing heavy atom: .R<ORA 5>.A<N4 11>
#   Added missing heavy atom: .R<ORA 5>.A<C7 12>
#   Added missing heavy atom: .R<ORA 5>.A<C8 13>
#   Added missing heavy atom: .R<ORA 5>.A<O3 14>
#   Added missing heavy atom: .R<ORA 5>.A<C9 15>
#   Added missing heavy atom: .R<ORB 10>.A<C5 4>
#   Added missing heavy atom: .R<ORB 10>.A<C4 5>
#   Added missing heavy atom: .R<ORB 10>.A<C3 6>
#   Added missing heavy atom: .R<ORB 10>.A<N3 7>
#   Added missing heavy atom: .R<ORB 10>.A<C1 8>
#   Added missing heavy atom: .R<ORB 10>.A<N1 9>
#   Added missing heavy atom: .R<ORB 10>.A<N2 11>
#   Added missing heavy atom: .R<ORB 10>.A<C2 12>
#   total atoms in file: 73
#   Leap added 124 missing atoms according to residue templates:
#        19 Heavy
#        105 H / lone pairs
# Checking Unit.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 19.218 angstroms between C9 and C2 atoms:
# -------  .R<ORA 5>.A<C9 15> and .R<ORB 10>.A<C2 12>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# The unperturbed charge of the unit (1.999998) is not zero.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# Ignoring the warnings from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
# old PREP-specified impropers:
#  <ORA 5>:  N1   N4   C1   N2
#  <ORB 10>:  N1   N2   C1   N3
#  total 28 improper torsions applied
#  2 improper torsions in old prep form
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	NSER	1
#   )
#  (no restraints)
# Writing pdb file: pep_vac.pdb
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#   Solute vdw bounding box:              15.618 23.259 19.952
#   Total bounding box for atom centers:  35.618 43.259 39.952
#   Solvent unit box:                     18.774 18.774 18.774
#   Total vdw box size:                   38.861 46.301 43.222 angstroms.
#   Volume: 77769.003 A^3
#   Total mass 32956.732 amu,  Density 0.704 g/cc
#   Added 1757 residues.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# addIons: 1st Ion & target unit have charges of the same sign:
#      unit charge = 2; ion1 charge = 1;
#      can't neutralize.
# 2 Cl- ions required to neutralize.
# Adding 2 counter ions to "pep" using 1A grid
# Grid extends from solute vdw + 2.51  to  8.42
# Resolution:      1.00 Angstrom.
# Solvent present: replacing closest with ion
# 	 when steric overlaps occur
# Calculating grid charges
# (Replacing solvent molecule)
# Placed Cl- in pep at (-1.11, -3.70, -11.46).
# (Replacing solvent molecule)
# Placed Cl- in pep at (-8.12, -3.74, 0.39).
#
# Done adding ions.
# Checking Unit.
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
# There is a bond of 19.218 angstroms between C9 and C2 atoms:
# -------  .R<ORA 5>.A<C9 15> and .R<ORB 10>.A<C2 12>
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
# old PREP-specified impropers:
#  <ORA 5>:  N1   N4   C1   N2
#  <ORB 10>:  N1   N2   C1   N3
#  total 28 improper torsions applied
#  2 improper torsions in old prep form
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	NSER	1
# 	WAT	1755
#   )
#  (no restraints)
# Writing pdb file: pep_solv.pdb
#    printing CRYST1 record to PDB file with box info
#
# /home/dahuilangda/Simulation/miniconda3/envs/stap/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
# 	Quit
#
# Exiting LEaP: Errors = 1; Warnings = 6; Notes = 9.

# %%
from stapep.molecular_dynamics import Simulation

sim = Simulation(output)
sim.setup(
        type='implicit', # 'explicit' or 'implicit'
        solvent='water', # 'water' or 'chloroform'
        temperature=300, # Kelvin
        friction=1, # ps^-1
        timestep=2, # fs
        interval=100, # ps
        nsteps=500000 # 1 ns
    )
sim.minimize()
sim.run()
# Out:
# INFO:parmed.structure:Adding bonds...
# INFO:parmed.structure:Adding angles...
# INFO:parmed.structure:Adding dihedrals...
# INFO:parmed.structure:Adding Ryckaert-Bellemans torsions...
# INFO:parmed.structure:Adding Urey-Bradleys...
# INFO:parmed.structure:Adding improper torsions...
# INFO:parmed.structure:Adding CMAP torsions...
# INFO:parmed.structure:Adding trigonal angle terms...
# INFO:parmed.structure:Adding out-of-plane bends...
# INFO:parmed.structure:Adding pi-torsions...
# INFO:parmed.structure:Adding stretch-bends...
# INFO:parmed.structure:Adding torsion-torsions...
# INFO:parmed.structure:Adding Nonbonded force...
# INFO:parmed.structure:Adding GB force...
# Minimizing...
# Running...
# Done! Time elapsed: 27.773070573806763 s
